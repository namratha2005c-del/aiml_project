# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached matplotlib-3.10.8-cp313-cp313-win_amd64.whl.metadata (52 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.1 MB 4.5 MB/s eta 0:00:02
#    --------- ------------------------------ 1.8/8.1 MB 4.5 MB/s eta 0:00:02
#    ------------ --------------------------- 2.6/8.1 MB 4.3 MB/s eta 0:00:02
#    ------------------ --------------------- 3.7/8.1 MB 4.4 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.7/8.1 MB 4.4 MB/s eta 0:00:01
#    --------------------------- ------------ 5.5/8.1 MB 4.4 MB/s eta 0:00:01
#    -------------------------------- ------- 6.6/8.1 MB 4.5 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.1 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 4.5 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
# ...

# %%
import matplotlib.pyplot as plt

# %%
x_data = np.random.random(50)
y_data = np.random.random(50)

x = [2000,2005,2009,2013,2015]
y = [40,56,77,63,80]

print(x_data)
print(y_data)
# Out:
# [0.77068941 0.78607065 0.4624729  0.34764726 0.44719264 0.59873319
#  0.75926832 0.7691208  0.6102101  0.92017811 0.15180513 0.79669106
#  0.18071096 0.09540056 0.27918188 0.97176477 0.58608398 0.52718572
#  0.92411622 0.50012774 0.01473453 0.27777432 0.95800963 0.08348193
#  0.19617947 0.80574747 0.34853632 0.70016753 0.91650679 0.10296743
#  0.061513   0.31176489 0.66804448 0.01381646 0.56241581 0.87090722
#  0.08238586 0.75973553 0.08535121 0.06753904 0.4635123  0.44049434
#  0.13623118 0.0782079  0.11930238 0.83328245 0.14965691 0.74552631
#  0.68902658 0.88462849]
# [0.04443294 0.02491207 0.72764468 0.07458308 0.946296   0.35120111
#  0.86655791 0.57364079 0.30461138 0.21205422 0.32862182 0.59834007
#  0.31015146 0.93615742 0.99203587 0.04113974 0.29599918 0.54770475
#  0.91514594 0.82872263 0.54291493 0.79019465 0.15660287 0.30284437
#  0.10859137 0.28417092 0.2492607  0.80103251 0.55101411 0.75995949
#  0.368228   0.65235691 0.10561056 0.1716087  0.15292134 0.36051397
# ...

# %%
print(len(x_data))
print(len(y_data))
print(len(x))
print(len(y))
# Out:
# 50
# 50
# 5
# 5

# %%
plt.grid()
plt.scatter(x_data,y_data, color='purple', s=50, marker="*", alpha=0.6)

# %%
print(x,y)
plt.plot(x,y)
# Out:
# [2000, 2005, 2009, 2013, 2015] [40, 56, 77, 63, 80]

# %%
years = [2002 + i for i in range(18)]
weights = [40,45,48,55,56,57,59,70,48,39,29,46,64,36,88,99,38,80,]

# %%
print(len(years))
print(len(weights))
# Out:
# 18
# 18

# %%
print(years)
print(weights)
# Out:
# [2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]
# [40, 45, 48, 55, 56, 57, 59, 70, 48, 39, 29, 46, 64, 36, 88, 99, 38, 80]

# %%
plt.plot(years,weights)

# %%
plt.title("Weight Graph")
plt.xlabel("Years")
plt.ylabel("weights")
plt.plot(years,weights)

# %%
plt.title("Weight Graph")
plt.xlabel("Years")
plt.ylabel("weights")
plt.plot(years,weights)

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
x1 = ['C++',"Python","Java","Mern","R","Go","AWS"]
y1 = [30,40,10,60,40,50,80]

plt.bar(x1,y1,  color='pink', align="edge", edgecolor = "brown", width=0.5, lw=4)
# Out:
# <BarContainer object of 7 artists>

# %%
ages = np.random.normal(20,2.5,500)
plt.hist(ages)
print(ages)
# Out:
# [24.71954369 23.24681754 18.2121144  18.6094276  16.38867811 16.89736143
#  16.85017825 15.20406801 18.55949521 22.3090465  19.33868903 18.51336653
#  21.84964437 19.5014863  22.40192709 18.13095023 16.42602391 15.32135735
#  21.0409248  16.03216373 21.39209077 20.68789096 16.9709393  18.65362109
#  17.88713365 22.5577387  22.86252026 19.9526616  19.78938124 19.11306124
#  21.94461916 22.35348308 20.28919189 20.56060145 21.48863081 19.36595962
#  20.1870538  17.10263503 19.10676821 19.58927101 18.76203675 16.26716466
#  22.30876219 24.34518901 21.47481651 25.21464371 20.33137944 22.51489003
#  20.74335519 18.73933163 18.35820868 23.75332768 19.90556652 20.52608563
#  19.85227046 22.76225654 20.39016796 17.93556191 18.99719703 21.81145823
#  18.63432275 19.36532448 19.21174589 15.97153899 20.67918982 20.40036827
#  19.80972423 14.47187497 19.98388271 22.97390288 17.47151791 20.49492492
#  21.74470504 20.65329956 17.06687245 21.43199923 19.09140196 18.69550082
# ...

# %%
plt.hist(ages,bins=6,cumulative=True)
# Out:
# (array([  5.,  48., 223., 428., 495., 500.]),
#  array([11.25339054, 14.10708173, 16.96077292, 19.81446411, 22.66815529,
#         25.52184648, 28.37553767]),
#  <BarContainer object of 6 artists>)

# %%
langs = ['C++',"Python","Java","Mern","R","Go","AWS"]
votes = [30,40,10,60,40,50,80]
plt.pie(votes,labels=langs)
# Out:
# ([<matplotlib.patches.Wedge at 0x27708045e50>,
# ...
#  [Text(1.0495531859022096, 0.3292994229611132, 'C++'),
#   Text(0.581860392213419, 0.9335086951781684, 'Python'),
#   Text(0.0557140519245607, 1.0985881596021994, 'Java'),
#   Text(-0.6733166615297373, 0.8698532481438748, 'Mern'),
#   Text(-1.0943562696531766, -0.11128501727898549, 'R'),
#   Text(-0.5818603106034915, -0.9335087460460177, 'Go'),
#   Text(0.7578635852335333, -0.7972720904289672, 'AWS')])

# %%
explodes = [0,0,0.2,0,0.1,0,0.2]
plt.pie(votes,labels=langs, explode=explodes,autopct="%.2f%%",pctdistance=1.4,startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x2770809a350>,
# ...
#  [Text(-0.32929956267590615, 1.0495531420664022, 'C++'),
#   Text(-0.9335086512489282, 0.581860462691363, 'Python'),
#   Text(-1.29833146422618, 0.06584382279533517, 'Java'),
#   Text(-0.8698531384466551, -0.6733168032468108, 'Mern'),
#   Text(0.12140203153336487, -1.1938431834791252, 'R'),
#   Text(0.933508563390432, -0.5818606036472411, 'Go'),
#   Text(0.9422305064040893, 0.8956571178757491, 'AWS')],
#  [Text(-0.4191085343147896, 1.3357949080845115, '9.68%'),
#   Text(-1.188101919771363, 0.7405496797890074, '12.90%'),
#   Text(-1.5979464175091445, 0.0810385511327202, '3.23%'),
#   Text(-1.10708581256847, -0.856948658677759, '19.35%'),
#   Text(0.15175253941670608, -1.4923039793489064, '12.90%'),
#   Text(1.1881018079514587, -0.7405498591873978, '16.13%'),
#   Text(1.1596683155742635, 1.1023472220009218, '25.81%')])

# %%
stocka = [100,52,85,75,25]
stockb = [85,62,85,4,45]
stockc = [89,35,47,56,85]

plt.plot(stocka, label="Company_1")
plt.plot(stockb, label="Company_2")
plt.plot(stockc, label="Company_3")
plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate values
s = np.arange(1, 101)
x = np.linspace(0, 10, 100)

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

# Plot Sine wave
axs[0, 0].plot(x, np.sin(x))
axs[0, 0].set_title("Sine Wave")

# Plot Cosine wave
axs[0, 1].plot(x, np.cos(x))
axs[0, 1].set_title("Cos Wave")

# Plot Random function
axs[1, 0].plot(x, np.random.random(100))
axs[1, 0].set_title("Random Function")

# Plot Logarithm function
axs[1, 1].plot(s, np.log(s))
axs[1, 1].set_title("Log Function")

# Display the plot
plt.tight_layout()
fig.suptitle("Four Graphs")
plt.savefig("Fourgraphs.png")
plt.show()

# %%
# Generate random data
data = np.random.rand(10, 12)  # 10 rows and 12 columns

# Create a heatmap
plt.imshow(data, cmap='viridis', interpolation='nearest')


# Add color bar
plt.colorbar()

# Set title and labels
plt.title("Random Heatmap")
plt.xlabel("X-axis Label")
plt.ylabel("Y-axis Label")

# Show the plot
plt.show()
